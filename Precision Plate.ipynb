# %%
import pandas as pd
#from pandas import*
#import pandas_datareader as pdr
import numpy as np
#import os
#os.getcwd()
#import pandas_datareader as pdr
import matplotlib.pyplot as plt
import seaborn as sns
#from sklearn.metrics import r2_score

# %%
df1= pd.read_csv('C:\\Users\\rratnappan\\Documents\\Confera\Precision Plate-1\\5-Average Combined_Plate-3.results.csv')

# %%
#df1.groupby('sample_name', as_index=False, sort=False)['AT_Dropout-Plate3'].mean()
df2= df1.groupby(['sample_name'], as_index=True).mean()

# %%
df2
df2.to_csv('C:\\Users\\rratnappan\\Documents\\Confera\Precision Plate-1\\6-Average Combined_Plate-3.results.csv')

# %%
df7= pd.read_csv('C:\\Users\\rratnappan\\Documents\\Confera\Precision Plate-1\\Quant2 Comparison.csv')#,skiprows=[i for i in range(24, 240)])

# %%
df8 = pd.DataFrame(df7, columns=['SAN-Plate-3-ng',"CAM Plate-1 ng"]) #,'SAN_GC_Dropout','CAM_GC_Dropout'])
df8.head()
# Out:
#    SAN-Plate-3-ng  CAM Plate-1 ng
# 0      395.821271      167.106653
# 1     1054.942183      424.330642
# 2      962.491118      419.467866
# 3      147.853536       93.107109
# 4      675.419818      286.819154

# %%
df6 = pd.DataFrame(df8, columns=['SAN-Plate-3-ng',"CAM Plate-1-ng"])
df6.head()


plt.figure (figsize=(10,10))
sns.set_style("whitegrid")
palette = ['#33FF3B', '#3379FF', '#FFD633', '#33FFF1']
plt.title("ccmf_perfect", fontsize=18)
plt.xlabel("Samples", fontweight='normal', fontsize=14)
plt.ylabel("", fontweight='normal', fontsize=14)
#plt.axhline(3)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

#sns.despine(bottom=True) # removes right and top axis lines
#plt.axhline(y=15, color='#ff3300', linestyle='--', linewidth=1, label='Threshold Value = 5')
#plt.legend(bbox_to_anchor=(0.31, 1.06), loc=2, borderaxespad=1., framealpha=1, facecolor ='white', frameon=True)


vals, names, xs = [],[],[]
for i, col in enumerate(df6.columns):
    vals.append(df6[col].values)
    names.append(col)
    xs.append(np.random.normal(i + 1, 0.04, df6[col].values.shape[0]))  # adds jitter to the data points - can be adjusted

plt.boxplot(vals, labels=names, notch=False)#, #, boxprops=boxprops, whiskerprops=whiskerprops,capprops=capprops, flierprops=flierprops, medianprops=medianprops,showmeans=False)
palette = ['r', 'g', 'b', 'y']
for x, val, c in zip(xs, vals, palette):
    plt.scatter(x, val, alpha=0.9, color=c)
plt.show()

# %%
df7.plot.bar(x='sample_name', y=['SAN-Plate-3-ng',"CAM Plate-1-ng"], rot=100, figsize=(16,12))
plt.legend(loc=1, prop={'size': 18})
plt.title("ccmf_perfect", fontsize=28)
plt.xlabel('Samples', fontsize=18)
plt.ylabel('', fontsize=16)
plt.axhline(.00032)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sample_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df10= pd.read_csv('C:\\Users\\rratnappan\\Documents\\Confera\Precision Plate-1\\4-Combined_Plate-3.results.csv', skiprows=[i for i in range(15, 1200)])

# %%
d = df10.boxplot(column = ['AT_Dropout-SAN-3', 'AT_Dropout-CAM-1'], by = 'sample_name')
d
# Out:
# array([<AxesSubplot:title={'center':'AT_Dropout-SAN-3'}, xlabel='sample_name'>,
#        <AxesSubplot:title={'center':'AT_Dropout-CAM-1'}, xlabel='sample_name'>],
#       dtype=object)

# %%
from plotnine import ggplot, aes, geompoint
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [288], in <cell line: 1>()
# ----> 1 from plotnine import ggplot, aes, geompoint
#
# ImportError: cannot import name 'geompoint' from 'plotnine' (C:\Users\rratnappan\Anaconda3\lib\site-packages\plotnine\__init__.py)

# %%
# !pip install plotnine

# %%
from plotnine import ggplot, aes, geomplot
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [210], in <cell line: 1>()
# ----> 1 from plotnine import ggplot, aes, geomplot
#
# ImportError: cannot import name 'geomplot' from 'plotnine' (C:\Users\rratnappan\Anaconda3\lib\site-packages\plotnine\__init__.py)

# %%
import plotnine as p9

# %%
gg=pd.DataFrame(df10, columns=['AT_Dropout-SAN-3'])
tt=pd.DataFrame(df10, columns=['AT_Dropout-CAM-1'])
(p9.ggplot(data=df10,
           mapping=p9.aes(x='sample_name',
                          y='gg'))
    + p9.geom_boxplot(colour="rebeccapurple", fill="lightskyblue")
    + p9.geom_jitter(alpha=0)
    + p9.geom_boxplot(alpha=0)
    + p9.theme(axis_text_x = p9.element_text(angle=90))
    
)
#q + theme(axis.text.x = element_text(angle = 90, vjust = 0.5, hjust=1))
# Out:
# <ggplot: (142446475499)>

# %%
g=pd.DataFrame(df10, columns=['sample_name','AT_Dropout-SAN-3','AT_Dropout-CAM-1'])
f=pd.DataFrame(pd.melt(g, id_vars=['sample_name'], value_name='AT_Dropout-SAN-3'))
f
f["period"] = f["sample_name"] + f["variable"]
f
# Out:
# C:\Users\rratnappan\AppData\Local\Temp\ipykernel_12676\3239030245.py:2: FutureWarning: This dataframe has a column name that matches the 'value_name' column name of the resulting Dataframe. In the future this will raise an error, please set the 'value_name' parameter of DataFrame.melt to a unique name.
#             sample_name          variable  AT_Dropout-SAN-3  \
# 0    ORD-0908729-01_0p5  AT_Dropout-SAN-3          5.428848
# 1    ORD-0908729-01_0p5  AT_Dropout-SAN-3          5.714508
# 2      ORD-0908729-01_1  AT_Dropout-SAN-3          5.565518
# 3      ORD-0908729-01_1  AT_Dropout-SAN-3          5.725856
# 4   ORD-0908729-01_Neat  AT_Dropout-SAN-3          5.206868
# 5   ORD-0908729-01_Neat  AT_Dropout-SAN-3          4.600485
# 6    ORD-0946316-01_0p5  AT_Dropout-SAN-3          5.604643
# 7    ORD-0946316-01_0p5  AT_Dropout-SAN-3          5.529785
# 8      ORD-0946316-01_1  AT_Dropout-SAN-3          5.281236
# 9      ORD-0946316-01_1  AT_Dropout-SAN-3          5.779433
# ...

# %%
sns.boxplot(x ='period', y = "AT_Dropout-SAN-3", data = f)
# Out:
# <AxesSubplot:xlabel='period', ylabel='AT_Dropout-SAN-3'>

# %%
(p9.ggplot(data=f,
           mapping=p9.aes(x='period',
                          y='AT_Dropout-SAN-3'))
    + p9.geom_boxplot(colour="rebeccapurple", fill="lightskyblue")
    + p9.geom_jitter(alpha=0)
    + p9.geom_boxplot(alpha=0)
    + p9.theme(axis_text_x = p9.element_text(angle=90))
  
)
# Out:
# <ggplot: (142449382397)>

# %%
x=df(1,2,3,3,4,5,5,7,9,9,15,25)
y=df(5,6,7,7,8,10,1,1,15,23,44,76)
z=df(15,15,15,16,19,25,29,30,55,79)
boxplot(x,y,z,
        horizontal=TRUE,
        names=c("Level 1","Level 2","Level 3"),
        col=c("red","yellow","blue"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [252], in <cell line: 1>()
# ----> 1 x=df(1,2,3,3,4,5,5,7,9,9,15,25)
#       2 y=df(5,6,7,7,8,10,1,1,15,23,44,76)
#       3 z=df(15,15,15,16,19,25,29,30,55,79)
#
# NameError: name 'df' is not defined

# %%
df12= pd.read_csv('C:\\Users\\rratnappan\\Documents\\Confera\Precision Plate-1\\9-ccmf-Plate-3_230210_A01874_0093_BHLLF5DSX5.0.7.2.results.csv')
df12
# Out:
#      Tissue-Sample  ccmf_perfect-Plate-3  ccmf_perfect-Plate-1
# 0    Prostate1_0p5              0.000000              0.000060
# 1    Prostate1_0p5              0.000000              0.000033
# 2      Prostate1_1              0.000069              0.000035
# 3      Prostate1_1              0.000124              0.000034
# 4   Prostate1_Neat              0.000481              0.000543
# ..             ...                   ...                   ...
# 57       CRC3_Neat              0.088043              0.084135
# 58          CRC3_1              0.001375              0.001432
# 59        CRC3_0p5              0.000919              0.000589
# 60           PMC-1              0.000248              0.000669
# 61           PMC-1              0.000093              0.000259
#
# [62 rows x 3 columns]

# %%
#df1.groupby('sample_name', as_index=False, sort=False)['AT_Dropout-Plate3'].mean()
df13= df12.groupby(['Tissue-Sample'], as_index=False).mean()

# %%
df13
df13.to_csv('C:\\Users\\rratnappan\\Documents\\Confera\\Precision Plate-1\\11-Average ccmf.results.csv')
df15 = pd.DataFrame(df4, columns=['Tissue-Sample',"ccmf_perfect-Plate-3",'ccmf_perfect-Plate-1' ])
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Input In [405], in <cell line: 2>()
#       1 df13
# ----> 2 df13.to_csv('C:\\Users\\rratnappan\\Documents\\Confera\\Precision Plate-1\\11-Average ccmf.results.csv')
#       3 df15 = pd.DataFrame(df4, columns=['Tissue-Sample',"ccmf_perfect-Plate-3",'ccmf_perfect-Plate-1' ])
#
# File ~\Anaconda3\lib\site-packages\pandas\core\generic.py:3551, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3540 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3542 formatter = DataFrameFormatter(
#    3543     frame=df,
#    3544     header=header,
#    (...)
#    3548     decimal=decimal,
#    3549 )
# ...

# %%
df14= pd.read_csv('C:\\Users\\rratnappan\\Documents\\Confera\Precision Plate-1\\11-Average ccmf.results.csv')
df14
# Out:
#     Unnamed: 0  ccmf_perfect-Plate-3  ccmf_perfect-Plate-1
# 0            0              0.000000              0.000060
# 1            1              0.000000              0.000033
# 2            2              0.000069              0.000035
# 3            3              0.000124              0.000034
# 4            4              0.000481              0.000543
# ..         ...                   ...                   ...
# 57          57              0.088043              0.084135
# 58          58              0.001375              0.001432
# 59          59              0.000919              0.000589
# 60          60              0.000248              0.000669
# 61          61              0.000093              0.000259
#
# [62 rows x 3 columns]

# %%
df13 = pd.DataFrame(df12, columns=['ccmf_perfect-Plate-3',"ccmf_perfect-Plate-1"])
df6.head()


plt.figure (figsize=(10,10))
sns.set_style("whitegrid")
palette = ['#33FF3B', '#3379FF', '#FFD633', '#33FFF1']
plt.title("ccmf_perfect", fontsize=18)
plt.xlabel("Samples", fontweight='normal', fontsize=14)
plt.ylabel("", fontweight='normal', fontsize=14)
#plt.axhline(3)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

#sns.despine(bottom=True) # removes right and top axis lines
#plt.axhline(y=15, color='#ff3300', linestyle='--', linewidth=1, label='Threshold Value = 5')
#plt.legend(bbox_to_anchor=(0.31, 1.06), loc=2, borderaxespad=1., framealpha=1, facecolor ='white', frameon=True)


vals, names, xs = [],[],[]
for i, col in enumerate(df6.columns):
    vals.append(df6[col].values)
    names.append(col)
    xs.append(np.random.normal(i + 1, 0.04, df6[col].values.shape[0]))  # adds jitter to the data points - can be adjusted

plt.boxplot(vals, labels=names, notch=False)#, #, boxprops=boxprops, whiskerprops=whiskerprops,capprops=capprops, flierprops=flierprops, medianprops=medianprops,showmeans=False)
palette = ['r', 'g', 'b', 'y']
for x, val, c in zip(xs, vals, palette):
    plt.scatter(x, val, alpha=0.9, color=c)
plt.show()

# %%
df13.plot.bar(x='Tissue-Sample', y=['ccmf_perfect-Plate-3',"ccmf_perfect-Plate-1"], rot=100, figsize=(16,12))
plt.legend(loc=1, prop={'size': 18})
plt.title("ccmf_perfect-Healthy Samples", fontsize=28)
plt.xlabel('Validation_Sample Name', fontsize=18)
plt.ylabel('', fontsize=16)
plt.axhline(.0003)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Tissue-Sample'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(rc={'figure.figsize':(15,18.27)})
df16= pd.read_csv('C:\\Users\\rratnappan\\Documents\\Confera\Precision Plate-1\\11-Average ccmf.results.csv', skiprows=[i for i in range(15, 1200)])

df16
# Out:
#             Sample          Unnamed: 1  ccmf_perfect-Plate-3  \
# 0    Prostate1_0p5   SAN-Prostate1_0p5              0.000000
# 1    Prostate1_0p5   SAN-Prostate1_0p5              0.000000
# 2      Prostate1_1     SAN-Prostate1_1              0.000069
# 3      Prostate1_1     SAN-Prostate1_1              0.000124
# 4   Prostate1_Neat  SAN-Prostate1_Neat              0.000481
# 5   Prostate1_Neat  SAN-Prostate1_Neat              0.000563
# 6    Prostate2_0p5   SAN-Prostate2_0p5              0.000468
# 7    Prostate2_0p5   SAN-Prostate2_0p5              0.000438
# 8      Prostate2_1     SAN-Prostate2_1              0.000992
# 9      Prostate2_1     SAN-Prostate2_1              0.000868
# 10  Prostate2_Neat  SAN-Prostate2_Neat              0.073941
# 11  Prostate2_Neat  SAN-Prostate2_Neat              0.076460
# 12       NSCL1_0p5       SAN-NSCL1_0p5              0.000447
# 13       NSCL1_0p5       SAN-NSCL1_0p5              0.000286
#
# ...

# %%
g=pd.DataFrame(df16, columns=['Sample','ccmf_perfect-Plate-3','ccmf_perfect-Plate-1'])
f=pd.DataFrame(pd.melt(g, id_vars=['Sample'], value_name='ccmf_perfect'))
f
f["period"] = f["Sample"] + f["variable"]
f
# Out:
#            Sample              variable  ccmf_perfect  \
# 0   Prostate1_0p5  ccmf_perfect-Plate-3      0.000000
# 1   Prostate1_0p5  ccmf_perfect-Plate-3      0.000000
# 2     Prostate1_1  ccmf_perfect-Plate-3      0.000069
# 3     Prostate1_1  ccmf_perfect-Plate-3      0.000124
# 4  Prostate1_Neat  ccmf_perfect-Plate-3      0.000481
# 5   Prostate1_0p5  ccmf_perfect-Plate-1      0.000060
# 6   Prostate1_0p5  ccmf_perfect-Plate-1      0.000033
# 7     Prostate1_1  ccmf_perfect-Plate-1      0.000035
# 8     Prostate1_1  ccmf_perfect-Plate-1      0.000034
# 9  Prostate1_Neat  ccmf_perfect-Plate-1      0.000543
#
#                                period
# 0   Prostate1_0p5ccmf_perfect-Plate-3
# 1   Prostate1_0p5ccmf_perfect-Plate-3
# 2     Prostate1_1ccmf_perfect-Plate-3
# 3     Prostate1_1ccmf_perfect-Plate-3
# 4  Prostate1_Neatccmf_perfect-Plate-3
# 5   Prostate1_0p5ccmf_perfect-Plate-1
# 6   Prostate1_0p5ccmf_perfect-Plate-1
# 7     Prostate1_1ccmf_perfect-Plate-1
# ...

# %%
sns.set_theme(style='whitegrid')

# %%
sns.boxplot(x ='Sample', y = 'ccmf_perfect', data = f)
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2]),
#  [Text(0, 0, 'Prostate1_0p5'),
#   Text(1, 0, 'Prostate1_1'),
#   Text(2, 0, 'Prostate1_Neat')])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df16= pd.read_csv('C:\\Users\\rratnappan\\Documents\\Confera\Precision Plate-1\\12-Average ccmf.results.csv', skiprows=[i for i in range(25, 1200)])

df16
# Out:
#               Sample  ccmf_perfect  Unnamed: 2  Unnamed: 3  Unnamed: 4
# 0      SAN:Breast1_1      0.000068         NaN         NaN         NaN
# 1      SAN:Breast1_1      0.000022         NaN         NaN         NaN
# 2      CAM:Breast1_1      0.000063         NaN         NaN         NaN
# 3      CAM:Breast1_1      0.000036         NaN         NaN         NaN
# 4    SAN:Breast1_0p5      0.000137         NaN         NaN         NaN
# 5    SAN:Breast1_0p5      0.000057         NaN         NaN         NaN
# 6    CAM:Breast1_0p5      0.000041         NaN         NaN         NaN
# 7    CAM:Breast1_0p5      0.000130         NaN         NaN         NaN
# 8   SAN:Breast1_Neat      0.000244         NaN         NaN         NaN
# 9   SAN:Breast1_Neat      0.000152         NaN         NaN         NaN
# 10  CAM:Breast1_Neat      0.000202         NaN         NaN         NaN
# 11  CAM:Breast1_Neat      0.000260         NaN         NaN         NaN
# ...

# %%
sns.boxplot(x ='Sample', y = 'ccmf_perfect', data = df16)
plt.xticks(rotation=90)
#plt.axvline(5.8, 0,0.17)
plt.grid(b=True, which='major', color='b', linestyle="dotted")#dashed')
# Out:
# C:\Users\rratnappan\AppData\Local\Temp\ipykernel_21400\2119848804.py:4: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=True, which='major', color='b', linestyle="dotted")#dashed')
