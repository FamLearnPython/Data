# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.set_theme(style="whitegrid")

# %%
tips = sns.load_dataset("tips")

# %%
ax=sns.violinplot(x=tips["total_bill"])

# %%
ax=sns.violinplot(x="day", y="total_bill", data=tips)

# %%
import pandas as pd

# %%
import pandas as pd

# %%
import pandas as pd

# %%
ax=sns.violinplot(x="day", y="total_bill", data=tips)

# %%
l1 = ["eat", "sleep", "repeat"]

# %%
l2 = ["ten"]

# %%
ob1=enumerate (l1)

# %%
on2=enumerate (l2)

# %%
print ("Return type:", type(ob1))
print (list(enumerate(l1, 30)))
# Out:
# Return type: <class 'enumerate'>
# [(30, 'eat'), (31, 'sleep'), (32, 'repeat')]

# %%
# testing code
if mystring == "hello":
    print("String: %s" % mystring)
if isinstance(myfloat, float) and myfloat == 10.0:
    print("Float: %f" % myfloat)
if isinstance(myint, int) and myint == 20:
    print("Integer: %d" % myint)
# Out:
# String: hello
# Float: 10.000000
# Integer: 20

# %%
type(-10)
# Out:
# int

# %%
type(1.222)
# Out:
# float

# %%
type(int)
# Out:
# type

# %%
def gh(y):
    if type (y) == int or type(y) == float or type(y) == str or type(y) == tuple or type(y) == list:
        return("kkk")
print (gh(1.0999))
# Out:
# kkk

# %%
Jack = ['pearl', 'rum', 'yoho']
print(Jack[0])
# Out:
# pearl

# %%
print ('Jacks favorite drink is : ')
print (Jack[1]  + (Jack[2]))
# Out:
# Jacks favorite drink is :
# rumyoho

# %%
Jack.append('Barbosa')

# %%
print(Jack)
# Out:
# ['pearl', 'rum', 'yoho', 'Barbosa']

# %%
Jack[3]
# Out:
# 'Barbosa'

# %%
J=len(Jack)
print(J)
# Out:
# 4

# %%
J = len(Jack)
print("There are %s number of items in jack: " % (J))
print (Jack)
# Out:
# There are 4 number of items in jack:
# ['pearl', 'rum', 'yoho', 'Barbosa']

# %%
#for i in range (len(PanM_PanS_PanP.Start_Position)) :
gg = PanM_PanS_PanP['Start_Position'].value_counts()[8115874]
gggg= PanM_PanS_PanP.count(8115874)
print(gg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 #for i in range (len(PanM_PanS_PanP.Start_Position)) :
# ----> 2 gg = PanM_PanS_PanP['Start_Position'].value_counts()[8115874]
#       3 gggg= PanM_PanS_PanP.count(8115874)
#       4 print(gg)
#
# NameError: name 'PanM_PanS_PanP' is not defined

# %%
hn = input('what re you : ')
print(hn + ' trick or treat')
# Out:
# what re you : Boo
# Boo trick or treat

# %%
df= pd.read_cdv("C:\\Users\\rratnappan\\Documents\\test.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 df= pd.read_cdv("C:\\Users\\rratnappan\\Documents\\test.csv")
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
import seaborn as sns

# %%
df1= pd.read_csv("C:\\Users\\rratnappan\\Documents\\R-lab\\test.csv")

# %%
sns.boxplot(x = df1['Name'],
            y = df1['Data'],
            hue = df1['Data'])
# Out:
# <AxesSubplot:xlabel='Name', ylabel='Data'>

# %%
>>> dna="atgctggggact"
>>> dna[:3]
>>> dna
# Out:
# 'atgctggggact'

# %%
df1= pd.read_csv("C:\\Users\\rratnappan\OneDrive - Foundation Medicine Inc\\Desktop\\Precision Plate-3_1.csv")
df1
# Out:
#     Sample_Name    Type Assay_Plate_Well  Sample_#  Replicate_#  RFU_Raw  \
# 0         blank   blank               B4       NaN            1    1.741
# 1         blank   blank              B12       NaN            2    1.364
# 2         blank   blank              B20       NaN            3    1.441
# 3         blank   blank               D4       NaN            4    1.686
# 4         blank   blank              D12       NaN            5    1.767
# ..          ...     ...              ...       ...          ...      ...
# 319          72  sample              P17      72.0            3    5.876
# 320          71  sample              N17      71.0            3    3.855
# 321          70  sample              L17      70.0            3    3.623
# 322          79  sample              N19      79.0            3    4.365
# 323          78  sample              L19      78.0            3    4.976
#
#        CV_Raw  Min_Diff_Over_Mean  RFU_Median_Reduced  In_Range  ...  \
# ...

# %% [markdown]
# df1
