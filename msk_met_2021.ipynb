# %%
import pandas as pd
import matplotlib as plt

# %%
#import csv
#with open (
#'C:\\Users\\rratnappan\\Documents\\Test_Data_Python\\cBioPortal\\msk_met_2021.tar\\msk_met_2021\\data_clinical_patient.txt', 'r') as f:
    #first_column = [row[0:10] for row in csv.reader(f,delimiter='\t')]
    #print (first_column[4:5])

# %%
New = pd.read_csv(r'C:\\Users\\rratnappan\\Documents\\Test_Data_Python\\cBioPortal\\msk_met_2021.tar\\msk_met_2021\\data_clinical_patient.txt', sep ='\t')
New.head(10)
# Out:
#                           #Patient Identifier     Sex  \
# 0  #Identifier to uniquely specify a patient.     Sex
# 1                                     #STRING  STRING
# 2                                          #0       1
# 3                                  PATIENT_ID     SEX
# 4                                   P-0000004  Female
# 5                                   P-0000015  Female
# 6                                   P-0000024  Female
# 7                                   P-0000025  Female
# 8                                   P-0000026  Female
# 9                                   P-0000027  Female
#
#                                     Race Category  \
# 0  The text for reporting information about race.
# 1                                          STRING
# 2                                               1
# 3                                            RACE
# 4                                           White
# 5                                           White
# ...

# %%
New.to_csv("C:\\Users\\rratnappan\\Documents\\Test_Data_Python\\cBioPortal\\msk_met_2021.tar\\msk_met_2021\\Patient.csv", index= False)

# %%
df = pd.read_csv("C:\\Users\\rratnappan\\Documents\\Test_Data_Python\\cBioPortal\\msk_met_2021.tar\\msk_met_2021\\Patient.csv", skiprows=4, )
#df.to_csv("new_csv.csv",index=False)

df.to_csv("C:\\Users\\rratnappan\\Documents\\Test_Data_Python\\cBioPortal\\msk_met_2021.tar\\msk_met_2021\\data_clinical_patient.csv" , index= False,)

# %%
Sample = pd.read_csv(r'C:\\Users\\rratnappan\\Documents\\Test_Data_Python\\cBioPortal\\msk_met_2021.tar\\msk_met_2021\\data_clinical_sample.txt', sep ='\t')
Sample.head(10)
# Out:
# C:\Users\rratnappan\AppData\Local\Temp\ipykernel_25108\3717697129.py:1: DtypeWarning: Columns (10,11,12,13,14,17,18,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   Sample = pd.read_csv(r'C:\\Users\\rratnappan\\Documents\\Test_Data_Python\\cBioPortal\\msk_met_2021.tar\\msk_met_2021\\data_clinical_sample.txt', sep ='\t')
#              #Sample Identifier                         Patient Identifier  \
# 0  #A unique sample identifier.  Identifier to uniquely specify a patient.
# 1                       #STRING                                     STRING
# 2                            #0                                          0
# 3                     SAMPLE_ID                                 PATIENT_ID
# 4             P-0000004-T01-IM3                                  P-0000004
# 5             P-0000015-T01-IM3                                  P-0000015
# 6             P-0000024-T01-IM3                                  P-0000024
# ...

# %%
Sample.to_csv("C:\\Users\\rratnappan\\Documents\\Test_Data_Python\\cBioPortal\\msk_met_2021.tar\\msk_met_2021\\Sample.csv", index= False)

# %%
df2 = pd.read_csv("C:\\Users\\rratnappan\\Documents\\Test_Data_Python\\cBioPortal\\msk_met_2021.tar\\msk_met_2021\\Sample.csv", skiprows=4, )
#df2.to_csv("C:\\Users\\rratnappan\\Documents\\Test_Data_Python\\cBioPortal\\msk_met_2021.tar\\msk_met_2021\\data_clinical_sample.csv" , index= False,)

# %%
patient_sample=pd.read_csv("C:\\Users\\rratnappan\\Documents\\Test_Data_Python\\cBioPortal\\msk_met_2021.tar\\msk_met_2021\\data_clinical_sample.csv")

patient_sample.head()
# Out:
#            SAMPLE_ID PATIENT_ID ORGAN_SYSTEM ONCOTREE_CODE  \
# 0  P-0000004-T01-IM3  P-0000004       Breast           IDC
# 1  P-0000015-T01-IM3  P-0000015       Breast           IDC
# 2  P-0000024-T01-IM3  P-0000024  Gynecologic           UEC
# 3  P-0000025-T02-IM5  P-0000025  Gynecologic           USC
# 4  P-0000026-T01-IM3  P-0000026  Gynecologic           UEC
#
#                   SUBTYPE SUBTYPE_ABBREVIATION SAMPLE_TYPE PRIMARY_SITE  \
# 0  Breast Ductal HR+HER2-         IDC HR+HER2-     Primary       Breast
# 1  Breast Ductal HR+HER2-         IDC HR+HER2-  Metastasis       Breast
# 2    Uterine Endometrioid            UCEC ENDO  Metastasis       Uterus
# 3          Uterine Serous          UCEC SEROUS  Metastasis       Uterus
# 4    Uterine Endometrioid            UCEC ENDO  Metastasis       Uterus
#
#    METASTATIC_SITE GENE_PANEL  ...  DMETS_DX_ADRENAL_GLAND  DMETS_DX_KIDNEY  \
# 0              NaN  IMPACT341  ...                      No               No
# ...

# %%
CancerType = patient_sample.groupby(by='ORGAN_SYSTEM')
for ORGAN_SYSTEM, i in CancerType:
    print(ORGAN_SYSTEM + " : " + str(len(i)))

# %%
df5 = patient_sample[patient_sample ['ORGAN_SYSTEM'] == 'Breast']
df5.to_csv("C:\\Users\\rratnappan\\Documents\\Test_Data_Python\\cBioPortal\\msk_met_2021.tar\\msk_met_2021\\data_clinical_sample_breast.csv" , index= False,)

# %%
CancerType = df5.groupby(by='SUBTYPE')
for SUBTYPE, i in CancerType:
    print(SUBTYPE + " : " + str(len(i)))
# Out:
# Breast Ductal HR+HER2+ : 256
# Breast Ductal HR+HER2- : 1524
# Breast Ductal HR-HER2+ : 115
# Breast Ductal Triple Negative : 341
# Breast Lobular HR+ : 373

# %%
Mutation = pd.read_csv(r'C:\\Users\\rratnappan\\Documents\\Test_Data_Python\\cBioPortal\\msk_met_2021.tar\\msk_met_2021\\data_mutations.txt', sep ='\t')
Mutation.head(10)
# Out:
# C:\Users\rratnappan\AppData\Local\Temp\ipykernel_25108\799678641.py:1: DtypeWarning: Columns (44,48,87) have mixed types. Specify dtype option on import or set low_memory=False.
#   Mutation = pd.read_csv(r'C:\\Users\\rratnappan\\Documents\\Test_Data_Python\\cBioPortal\\msk_met_2021.tar\\msk_met_2021\\data_mutations.txt', sep ='\t')
#   Hugo_Symbol  Entrez_Gene_Id Center NCBI_Build Chromosome  Start_Position  \
# 0        TP53            7157  MSKCC     GRCh37         17         7577121
# 1         FYN            2534  MSKCC     GRCh37          6       111983080
# 2       KDM5C            8242  MSKCC     GRCh37          X        53246994
# 3        KRAS            3845  MSKCC     GRCh37         12        25380275
# 4       RAD50           10111  MSKCC     GRCh37          5       131911521
# 5        TP53            7157  MSKCC     GRCh37         17         7572963
# 6       PTPRD            5789  MSKCC     GRCh37          9         8486211
# ...

# %%
Mutation.to_csv('C:\\Users\\rratnappan\\Documents\\Test_Data_Python\\cBioPortal\\msk_met_2021.tar\\msk_met_2021\\data_mutations.csv', index= False)

# %%
def iterrow_example(Mutation, Hugo_Symbol):
    for i, row in Mutation.iterrows():
        val = row[col]
        if val == "TP53":
            return (row['Start_Position'])
        else:
            return ("no")
iterrow_example[0:1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [172], in <cell line: 8>()
#       6         else:
#       7             return ("no")
# ----> 8 iterrow_example[0:1]
#
# TypeError: 'function' object is not subscriptable

# %%
OnlyTP53 = Mutation.Hugo_Symbol == "FYN"

# %%
Mutation[OnlyTP53]
# Out:
#        Hugo_Symbol  Entrez_Gene_Id Center NCBI_Build Chromosome  \
# 1              FYN            2534  MSKCC     GRCh37          6
# 2465           FYN            2534  MSKCC     GRCh37          6
# 2645           FYN            2534  MSKCC     GRCh37          6
# 2866           FYN            2534  MSKCC     GRCh37          6
# 3200           FYN            2534  MSKCC     GRCh37          6
# ...            ...             ...    ...        ...        ...
# 225089         FYN               0  MSKCC     GRCh37          6
# 229321         FYN               0  MSKCC     GRCh37          6
# 229370         FYN               0  MSKCC     GRCh37          6
# 230024         FYN               0  MSKCC     GRCh37          6
# 230067         FYN               0  MSKCC     GRCh37          6
#
#         Start_Position  End_Position Strand         Consequence  \
# 1            111983080     111983081      +  frameshift_variant
# 2465         112041191     112041191      +    missense_variant
# ...

# %%
Mutation[Mutation.Hugo_Symbol == "FYN"]
# Out:
#        Hugo_Symbol  Entrez_Gene_Id Center NCBI_Build Chromosome  \
# 1              FYN            2534  MSKCC     GRCh37          6
# 2465           FYN            2534  MSKCC     GRCh37          6
# 2645           FYN            2534  MSKCC     GRCh37          6
# 2866           FYN            2534  MSKCC     GRCh37          6
# 3200           FYN            2534  MSKCC     GRCh37          6
# ...            ...             ...    ...        ...        ...
# 225089         FYN               0  MSKCC     GRCh37          6
# 229321         FYN               0  MSKCC     GRCh37          6
# 229370         FYN               0  MSKCC     GRCh37          6
# 230024         FYN               0  MSKCC     GRCh37          6
# 230067         FYN               0  MSKCC     GRCh37          6
#
#         Start_Position  End_Position Strand         Consequence  \
# 1            111983080     111983081      +  frameshift_variant
# 2465         112041191     112041191      +    missense_variant
# ...
