# %%
import pandas as pd
import matplotlib as plt
import matplotlib.pyplot as plt
import numpy as np 
import seaborn as sns

# %%
df5= pd.read_excel('C:\\Users\\rratnappan\\Documents\\Confera\\GCDropOutTest\\RampRateTest-Results.xlsx')
df5.head()
# Out:
#   Samples  SAN_AT_Dropout  SAN_GC_Dropout  AT_Dropout-MixTest  \
# 0    PMC1        1.669828        1.488272            1.522293
# 1    PMC2        1.892998        3.660962            1.458303
# 2    PMC3        1.440811        2.648374            1.797875
# 3    PMC4        1.464505        2.361510            1.678926
# 4    PMC5        1.547773        1.862186            2.067131
#
#    GC_Dropout-MixTest  AT-RampTest  GC-RampTest
# 0            4.887249    10.814639     0.000009
# 1            4.392814     3.870012     0.005541
# 2            5.163367     3.396310     0.039823
# 3            4.831806     6.767449     0.000917
# 4            5.625996     5.307422     0.004191

# %%
df5.plot.bar(x='Samples', y=['SAN_GC_Dropout', 'GC_Dropout-MixTest', 'GC-RampTest'], rot=100, figsize=(16,12))
plt.legend(loc=1, prop={'size': 18})
plt.title("GC DropOut", fontsize=18)
plt.xlabel('Validation_Sample Name', fontsize=18)
plt.ylabel('', fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# Out:
# (array([0., 1., 2., 3., 4., 5., 6.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
df5.plot.bar(x='Samples', y=['GC-RampTest'], rot=100, figsize=(16,12))
plt.legend(loc=1, prop={'size': 18})
plt.title("GC DropOut", fontsize=18)
plt.xlabel('Validation_Sample Name', fontsize=18)
plt.ylabel('', fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
df5.plot.bar(x='Samples', y=['SAN_AT_Dropout', 'AT_Dropout-MixTest', 'AT-RampTest'], rot=100, figsize=(16,12))
plt.legend(loc=1, prop={'size': 18})
plt.title("GC DropOut", fontsize=18)
plt.xlabel('Validation_Sample Name', fontsize=18)
plt.ylabel('', fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# Out:
# (array([ 0.,  2.,  4.,  6.,  8., 10., 12.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
df5= pd.read_excel('C:\\Users\\rratnappan\\Documents\\Confera\\Bead Carry-Over Experiemtns\\Qubit Data.xlsx')
#df5 = df5.apply(lambda x: pd.Series(x.dropna().values))
#df5 = df5.fillna('')
df5.head()
# Out:
#   Sample Name  Hamilton: Pre-Height Adjustment  \
# 0       PMC-1                            1.280
# 1       PMC-2                            2.960
# 2       PMC-3                            2.450
# 3       PMC-4                            0.941
# 4       PMC-5                            0.902
#
#    Hamilton: Post-Height Adjustment
# 0                              7.02
# 1                              5.80
# 2                              9.10
# 3                              9.77
# 4                             14.10

# %%
df6 = pd.DataFrame(df5, columns=['Hamilton: Pre-Height Adjustment', 'Hamilton: Post-Height Adjustment'] )
df6.head()
# Out:
#    Hamilton: Pre-Height Adjustment  Hamilton: Post-Height Adjustment
# 0                            1.280                              7.02
# 1                            2.960                              5.80
# 2                            2.450                              9.10
# 3                            0.941                              9.77
# 4                            0.902                             14.10

# %%
vals, names, xs = [],[],[]
for i, col in enumerate(df6.columns):
    vals.append(df6[col].values)
    names.append(col)
    xs.append(np.random.normal(i + 1, 0.04, df6[col].values.shape[0]))  # adds jitter to the data points - can be adjusted

# %%
plt.figure (figsize=(10,10))
sns.set_style("whitegrid")
palette = ['#33FF3B', '#3379FF', '#FFD633', '#33FFF1']
plt.title("", fontsize=18)
plt.xlabel("PMCs", fontweight='normal', fontsize=14)
plt.ylabel("ng/ul", fontweight='normal', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.boxplot(vals, labels=names, notch=False, showbox=True, showmeans=True, showfliers=False)
#set_visible(True)#, #, boxprops=boxprops, whiskerprops=whiskerprops,capprops=capprops, flierprops=flierprops, medianprops=medianprops,showmeans=False)
palette = ['r', 'g', 'b', 'y']
for x, val, c in zip(xs, vals, palette):
    plt.scatter(x, val, alpha=1, color=c)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 10>()
#       7 plt.xticks(fontsize=14)
#       8 plt.yticks(fontsize=14)
# ---> 10 plt.violinplot(vals, labels=names, notch=False, showbox=True, showmeans=True, showfliers=False)
#      11 #set_visible(True)#, #, boxprops=boxprops, whiskerprops=whiskerprops,capprops=capprops, flierprops=flierprops, medianprops=medianprops,showmeans=False)
#      12 palette = ['r', 'g', 'b', 'y']
#
# TypeError: violinplot() got an unexpected keyword argument 'labels'

# %%
DevCon= pd.read_excel('C:\\Users\\rratnappan\\Documents\\Confera\\GCDropOutTest\\Attachment07_DevConfirmationSampleSummary.xlsx')
DevCon.head()
# Out:
#     nDNASampleName  Plate#  LCInput(ng)  Yield(ng)  AT_Dropout  GC_Dropout  \
# 0           SPE001  Plate4         20.0      514.3    1.912000    0.344000
# 1       SEN001_1_0  Plate1         10.0      271.4    4.339325    0.092729
# 2  REP005_2_0_rpt1  Plate1         10.0      524.3    3.577112    0.146247
# 3   REPBack_0_rpt3  Plate1         10.0      415.8    4.115228    0.093183
# 4           SPE032  Plate1         20.0      908.2    3.018540    0.060146
#
#   Mapped_Reads Predicted_Gender  Proper_Pair  SD_Methyl_Position_Bias  \
# 0    477943701        Uncertain        93.75                  0.03121
# 1    443541576             Male        91.46                  0.02351
# 2    485325747             Male        91.34                  0.02403
# 3    445685796             Male        92.35                  0.02336
# 4    392479351             Male        94.34                  0.02767
#
#    Mean_Unique_Coverage  ccmf_perfect  ctDNA_detected  \
# ...

# %%
df7 = pd.DataFrame(DevCon, columns=['AT_Dropout'])#,'SAN_GC_Dropout','CAM_GC_Dropout'])
df7.tail()
# Out:
#      AT_Dropout
# 604   10.453372
# 605    8.985096
# 606    6.323466
# 607   11.396635
# 608    3.216004

# %%
vals, names, xs = [],[],[]
for i, col in enumerate(df6.columns):
    vals.append(df6[col].values)
    names.append(col)
    xs.append(np.random.normal(i + 1, 0.04, df6[col].values.shape[0]))  # adds jitter to the data points - can be adjusted

# %%
plt.figure (figsize=(10,10))
sns.set_style("whitegrid")
palette = ['#33FF3B', '#3379FF', '#FFD633', '#33FFF1']
plt.title("Conversion_Eff", fontsize=18)
plt.xlabel("Samples", fontweight='normal', fontsize=14)
plt.ylabel("", fontweight='normal', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

#sns.despine(bottom=True) # removes right and top axis lines
#plt.axhline(y=15, color='#ff3300', linestyle='--', linewidth=1, label='Threshold Value = 5')
#plt.legend(bbox_to_anchor=(0.31, 1.06), loc=2, borderaxespad=1., framealpha=1, facecolor ='white', frameon=True)


plt.boxplot(vals, labels=names, notch=False)#, #, boxprops=boxprops, whiskerprops=whiskerprops,capprops=capprops, flierprops=flierprops, medianprops=medianprops,showmeans=False)
palette = ['r', 'g', 'b', 'y']
for x, val, c in zip(xs, vals, palette):
    plt.scatter(x, val, alpha=0.4, color=c)
plt.show()

# %%
sns.boxplot( y=df6[ "GC-Droupout_Ramp-2C/s", "AT-Droupout_Ramp-2C/s"])#, x=df["sepal_length"] )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('GC-Droupout_Ramp-2C/s', 'AT-Droupout_Ramp-2C/s')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df7= pd.read_excel('C:\\Users\\rratnappan\\Documents\\Confera\\GCDropOutTest\\Correlation.xlsx')
#df7 = df5.apply(lambda x: pd.Series(x.dropna().values))
#df7 = df5.fillna('')
df7.head()
# Out:
#    Ramp Temp  GCDropOut  ATDropOut
# 0        2.5   1.802629   1.389507
# 1        3.5   1.829766   1.200932
# 2        5.0   2.060028   1.441680

# %%
plt.plot(df7['Ramp Temp'], df7['ATDropOut'], 'o', color='green')

#obtain m (slope) and b(intercept) of linear regression line
m, b = np.polyfit(df7['Ramp Temp'], df7['GCDropOut'], 1)

#use red as color for regression line
plt.plot(x, m*x+b, color='red')

# %%
plt.figure (figsize=(10,10))
sns.set_style("whitegrid")
palette = ['#33FF3B', '#3379FF', '#FFD633', '#33FFF1']
plt.title("Increasing Ramp Rate", fontsize=18)
plt.xlabel("Ramp Temperature C/s", fontweight='normal', fontsize=14)
plt.ylabel("AT Drop Out", fontweight='normal', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

x= df7['Ramp Temp']
y= df7['ATDropOut']

#x=float(a)
#y=float(b)
#create basic scatterplot
plt.plot(x, y, 'o')

#obtain m (slope) and b(intercept) of linear regression line
m, b = np.polyfit(x, y, 1)

#add linear regression line to scatterplot 
plt.plot(x, m*x+b)
