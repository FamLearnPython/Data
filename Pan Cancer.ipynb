# %%
import pandas as pd

import matplotlib.pyplot as plt

# %%
PanS = pd.read_csv('C:\\Users\\rratnappan\\Documents\\Test_Data_Python\\cBioPortal\\brca_tcga_pan_can_atlas_2018\\brca_tcga_pan_can_atlas_2018\\data_clinical_sample.csv')

# %%
PanS.head()
# Out:
#      PATIENT_ID        SAMPLE_ID ONCOTREE_CODE    CANCER_TYPE  \
# 0  TCGA-3C-AAAU  TCGA-3C-AAAU-01           ILC  Breast Cancer
# 1  TCGA-3C-AALI  TCGA-3C-AALI-01           IDC  Breast Cancer
# 2  TCGA-3C-AALJ  TCGA-3C-AALJ-01           IDC  Breast Cancer
# 3  TCGA-3C-AALK  TCGA-3C-AALK-01           IDC  Breast Cancer
# 4  TCGA-4H-AAAK  TCGA-4H-AAAK-01           ILC  Breast Cancer
#
#                 CANCER_TYPE_DETAILED                      TUMOR_TYPE  GRADE  \
# 0  Breast Invasive Lobular Carcinoma  Infiltrating Lobular Carcinoma    NaN
# 1   Breast Invasive Ductal Carcinoma   Infiltrating Ductal Carcinoma    NaN
# 2   Breast Invasive Ductal Carcinoma   Infiltrating Ductal Carcinoma    NaN
# 3   Breast Invasive Ductal Carcinoma   Infiltrating Ductal Carcinoma    NaN
# 4  Breast Invasive Lobular Carcinoma  Infiltrating Lobular Carcinoma    NaN
#
#   TISSUE_PROSPECTIVE_COLLECTION_INDICATOR  \
# 0                                      No
# 1                                      No
# ...

# %%
PanM = pd.read_csv('C:\\Users\\rratnappan\\Documents\\Test_Data_Python\\cBioPortal\\brca_tcga_pan_can_atlas_2018\\brca_tcga_pan_can_atlas_2018\\data_mutations.csv')

# %%
#PanM.iloc[:1]

# %%
PanP = pd.read_csv('C:\\Users\\rratnappan\\Documents\\Test_Data_Python\\cBioPortal\\brca_tcga_pan_can_atlas_2018\\brca_tcga_pan_can_atlas_2018\\data_clinical_patient.csv')

# %%
#PanP.iloc[:1]

# %%
#PanM_PanS = pd.merge(PanM, PanS, on = "SAMPLE_ID", how = 'inner' )

# %%
#PanM_PanS.to_csv('C:\\Users\\rratnappan\\Documents\\Test_Data_Python\\cBioPortal\\brca_tcga_pan_can_atlas_2018\\brca_tcga_pan_can_atlas_2018\\PanM_PanS.csv')

# %%
#df= pd.read_csv('C:\\Users\\rratnappan\\Documents\\Test_Data_Python\\cBioPortal\\brca_tcga_pan_can_atlas_2018\\brca_tcga_pan_can_atlas_2018\\PanM_PanS.csv')

# %%
#df.iloc[:1]

# %%
PanM_PanS_PanP = pd.merge(PanM_PanS, PanP, on = "PATIENT_ID", how = 'inner' )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 PanM_PanS_PanP = pd.merge(PanM_PanS, PanP, on = "PATIENT_ID", how = 'inner' )
#
# NameError: name 'PanM_PanS' is not defined

# %%
#PanM_PanS_PanP.to_csv('C:\\Users\\rratnappan\\Documents\\Test_Data_Python\\cBioPortal\\brca_tcga_pan_can_atlas_2018\\brca_tcga_pan_can_atlas_2018\\PanM_PanS_PanP.csv')

# %%
PanM_PanS_PanP=pd.read_csv('C:\\Users\\rratnappan\\Documents\\Test_Data_Python\\cBioPortal\\brca_tcga_pan_can_atlas_2018\\brca_tcga_pan_can_atlas_2018\\PanM_PanS_PanP.csv', low_memory=False)

# %%
PanM_PanS_PanP.iloc[:1]
# Out:
#   Hugo_Symbol  Entrez_Gene_Id Center NCBI_Build Chromosome  Start_Position  \
# 0       GATA3          2625.0      .     GRCh37         10         8115874
#
#    End_Position Strand         Consequence Variant_Classification  ... WEIGHT  \
# 0       8115875      +  frameshift_variant        Frame_Shift_Ins  ...    NaN
#
#   IN_PANCANPATHWAYS_FREEZE OS_STATUS   OS_MONTHS                  DSS_STATUS  \
# 0                      Yes  0:LIVING  133.050597  0:ALIVE OR DEAD TUMOR FREE
#
#    DSS_MONTHS             DFS_STATUS DFS_MONTHS     PFS_STATUS PFS_MONTHS
# 0  133.050597  1:Recurred/Progressed  59.440444  1:PROGRESSION  59.440444
#
# [1 rows x 165 columns]

# %%
n_pt_variants2 = PanM_PanS_PanP.groupby(by='PATIENT_ID')

# %%
for PATIENT_ID, i in n_pt_variants2:
    print (PATIENT_ID + " : " + str(len(i)))
    #print (group)
    #print()
# Out:
# TCGA-3C-AAAU : 50
# TCGA-3C-AALI : 824
# TCGA-3C-AALJ : 72
# TCGA-3C-AALK : 69
# TCGA-4H-AAAK : 37
# TCGA-5L-AAT0 : 282
# TCGA-5T-A9QA : 93
# TCGA-A1-A0SB : 19
# TCGA-A1-A0SD : 44
# TCGA-A1-A0SE : 39
# TCGA-A1-A0SF : 67
# TCGA-A1-A0SG : 37
# TCGA-A1-A0SH : 143
# TCGA-A1-A0SI : 279
# TCGA-A1-A0SJ : 42
# TCGA-A1-A0SK : 88
# TCGA-A1-A0SM : 34
# TCGA-A1-A0SN : 80
# TCGA-A1-A0SO : 386
# TCGA-A1-A0SP : 75
# TCGA-A1-A0SQ : 40
# TCGA-A2-A04N : 57
# TCGA-A2-A04P : 180
# TCGA-A2-A04Q : 71
# TCGA-A2-A04R : 109
# TCGA-A2-A04T : 127
# TCGA-A2-A04U : 71
# TCGA-A2-A04V : 44
# TCGA-A2-A04W : 190
# TCGA-A2-A04X : 54
# TCGA-A2-A04Y : 66
# TCGA-A2-A0CK : 33
# TCGA-A2-A0CL : 205
# TCGA-A2-A0CM : 76
# TCGA-A2-A0CP : 52
# TCGA-A2-A0CQ : 51
# TCGA-A2-A0CR : 221
# TCGA-A2-A0CS : 57
# TCGA-A2-A0CT : 126
# TCGA-A2-A0CU : 64
# TCGA-A2-A0CV : 27
# TCGA-A2-A0CW : 93
# TCGA-A2-A0CX : 371
# TCGA-A2-A0CZ : 32
# TCGA-A2-A0D0 : 114
# TCGA-A2-A0D1 : 79
# TCGA-A2-A0D2 : 116
# TCGA-A2-A0D3 : 39
# TCGA-A2-A0D4 : 48
# ...

# %%
n_pt_variants=pd.DataFrame({"Mutation Per Patient" : n_pt_variants2.size(), "% of Total Mutation" : (n_pt_variants2.size() / (n_pt_variants2.size().sum())*100)}).reset_index()
n_pt_variants
# Out:
#         PATIENT_ID  Mutation Per Patient  % of Total Mutation
# 0     TCGA-3C-AAAU                    50             0.038317
# 1     TCGA-3C-AALI                   824             0.631461
# 2     TCGA-3C-AALJ                    72             0.055176
# 3     TCGA-3C-AALK                    69             0.052877
# 4     TCGA-4H-AAAK                    37             0.028354
# ...            ...                   ...                  ...
# 1004  TCGA-WT-AB44                    66             0.050578
# 1005  TCGA-XX-A899                   130             0.099624
# 1006  TCGA-XX-A89A                   271             0.207677
# 1007  TCGA-Z7-A8R5                    36             0.027588
# 1008  TCGA-Z7-A8R6                   117             0.089661
#
# [1009 rows x 3 columns]

# %%
n_pt_variants.to_csv('C:\\Users\\rratnappan\\Documents\\Test_Data_Python\\cBioPortal\\brca_tcga_pan_can_atlas_2018\\brca_tcga_pan_can_atlas_2018\\Patient-Mutations.csv')

# %%
PatientMut = pd.read_csv('C:\\Users\\rratnappan\\Documents\\Test_Data_Python\\cBioPortal\\brca_tcga_pan_can_atlas_2018\\brca_tcga_pan_can_atlas_2018\\Patient-Mutations.csv')

# %%
#PatientMut = PatientMut.rename({'count': 'mutations'}, axis='columns')
#PatientMut.head(2)

# %%
PatientMut.head()
# Out:
#    Unnamed: 0    PATIENT_ID  Mutation Per Patient  % of Total Mutation
# 0           0  TCGA-3C-AAAU                    50             0.038317
# 1           1  TCGA-3C-AALI                   824             0.631461
# 2           2  TCGA-3C-AALJ                    72             0.055176
# 3           3  TCGA-3C-AALK                    69             0.052877
# 4           4  TCGA-4H-AAAK                    37             0.028354

# %%
grouped_multiple = PanM_PanS_PanP.groupby(['Start_Position'])

# %%
TotalMutationsperGene = PanM_PanS_PanP.groupby(['Hugo_Symbol'])

for Hugo_Symbol, i in TotalMutationsperGene:
    print (Hugo_Symbol + " = " + str(len(i)))
    #print (Hugo_Symbol)
    #print()
# Out:
# 44621 = 10
# 44622 = 5
# 44623 = 4
# 44624 = 3
# 44625 = 7
# 44626 = 9
# 44627 = 6
# 44628 = 4
# 44630 = 17
# 44631 = 3
# 44805 = 5
# 44806 = 5
# 44807 = 9
# 44808 = 12
# 44809 = 4
# 44810 = 11
# 44811 = 4
# 44812 = 10
# 44813 = 6
# 44814 = 3
# 44815 = 4
# 44816 = 6
# 44818 = 5
# 44819 = 2
# 44896 = 2
# A1BG = 4
# A1CF = 11
# A2M = 18
# A2ML1 = 17
# A4GALT = 1
# A4GNT = 2
# AAAS = 4
# AACS = 6
# AADAC = 6
# AADACL2 = 6
# AADACL3 = 1
# AADACL4 = 6
# AADAT = 4
# AAED1 = 1
# AAGAB = 1
# AAK1 = 20
# AAMDC = 2
# AAMP = 1
# AANAT = 1
# AAR2 = 2
# AARD = 2
# AARS = 13
# AARS2 = 10
# AASDH = 7
# AASDHPPT = 7
# AASS = 8
# AATF = 3
# AATK = 8
# AATK-AS1 = 3
# ABAT = 8
# ABCA1 = 18
# ABCA10 = 15
# ABCA11P = 13
# ABCA12 = 29
# ABCA13 = 71
# ABCA17P = 1
# ABCA2 = 8
# ABCA3 = 24
# ABCA4 = 21
# ABCA5 = 19
# ABCA6 = 21
# ABCA7 = 16
# ABCA8 = 33
# ABCA9 = 26
# ABCB1 = 21
# ABCB10 = 13
# ABCB11 = 23
# ABCB4 = 21
# ABCB5 = 17
# ABCB6 = 10
# ABCB7 = 10
# ABCB8 = 12
# ABCB9 = 3
# ABCC1 = 17
# ...

# %%
#n_pt_variants=pd.DataFrame({"Mutation Per Patient" : n_pt_variants2.size(), "% of Total Mutation" : (n_pt_variants2.size() / (n_pt_variants2.size().sum())*100)}).reset_index()
#n_pt_variants





TMG=pd.DataFrame({"TotalMutationsperGene" : TotalMutationsperGene.size(), "% of TotalMutationPERGENE" : (TotalMutationsperGene.size() / (TotalMutationsperGene.size().sum())*100)}).reset_index()
TMG.head()
# Out:
#   Hugo_Symbol  TotalMutationsperGene  % of TotalMutationPERGENE
# 0       44621                     10                   0.007663
# 1       44622                      5                   0.003832
# 2       44623                      4                   0.003065
# 3       44624                      3                   0.002299
# 4       44625                      7                   0.005364

# %%
TMG.to_csv('C:\\Users\\rratnappan\\Documents\\Test_Data_Python\\cBioPortal\\brca_tcga_pan_can_atlas_2018\\brca_tcga_pan_can_atlas_2018\\TotalMutperGene.csv')

# %%
topmostTMG = TMG.nlargest(20,['% of TotalMutationPERGENE'])
topmostTMG
# Out:
#       Hugo_Symbol  TotalMutationsperGene  % of TotalMutationPERGENE
# 17376         TTN                    432                   0.331057
# 12105      PIK3CA                    416                   0.318796
# 16908        TP53                    372                   0.285077
# 10116       MUC16                    209                   0.160164
# 2854         CDH1                    141                   0.108053
# 9203       MAP3K1                    141                   0.108053
# 6079        GATA3                    140                   0.107287
# 8343        KMT2C                    131                   0.100390
# 14144        RYR2                    120                   0.091960
# 15950       SYNE1                    116                   0.088895
# 4592          DST                    104                   0.079699
# 5755          FLG                    104                   0.079699
# 7048        HMCN1                    100                   0.076634
# ...

# %%
df3=pd.DataFrame({"count" : GeneName.size()}).reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 df3=pd.DataFrame({"count" : GeneName.size()}).reset_index()
#
# NameError: name 'GeneName' is not defined

# %%
df3.to_csv('C:\\Users\\rratnappan\\Documents\\Test_Data_Python\\cBioPortal\\brca_tcga_pan_can_atlas_2018\\brca_tcga_pan_can_atlas_2018\\DF3.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 df3.to_csv('C:\\Users\\rratnappan\\Documents\\Test_Data_Python\\cBioPortal\\brca_tcga_pan_can_atlas_2018\\brca_tcga_pan_can_atlas_2018\\DF3.csv')
#
# NameError: name 'df3' is not defined

# %%
topmost= df3.nlargest(10,['count'])
topmost
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 topmost= df3.nlargest(10,['count'])
#       2 topmost
#
# NameError: name 'df3' is not defined

# %%
topmost.plot(x='Hugo_Symbol', y='count', kind='scatter', c='DarkBlue')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 topmost.plot(x='Hugo_Symbol', y='count', kind='scatter', c='DarkBlue')
#
# NameError: name 'topmost' is not defined

# %%
PanP = pd.read_csv('C:\\Users\\rratnappan\\Documents\\Test_Data_Python\\cBioPortal\\brca_tcga_pan_can_atlas_2018\\brca_tcga_pan_can_atlas_2018\\data_clinical_patient.csv')

# %%
n_mutations = [5, 10, 25, 50, 100, 200, 300, 400, 500]

# %%
Aa = PanP.groupby(by='SUBTYPE')

SubType=pd.DataFrame({"count" : Aa.size()}).reset_index()
SubType
# Out:
#        SUBTYPE  count
# 0   BRCA_Basal    171
# 1    BRCA_Her2     78
# 2    BRCA_LumA    499
# 3    BRCA_LumB    197
# 4  BRCA_Normal     36

# %%
table = pd.crosstab(index = n_mutations[], columns = )
# Out:
#   Input In [37]
#     table = pd.crosstab(index = n_mutations[], columns = )
#                                             ^
# SyntaxError: invalid syntax

# %%
PatientMut['% of Patients']=pd.cut(PatientMut['count'], n_mutations)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'count'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
PatientMut.head(10)
# Out:
#    Unnamed: 0    PATIENT_ID  Mutation Per Patient  % of Total Mutation
# 0           0  TCGA-3C-AAAU                    50             0.038317
# 1           1  TCGA-3C-AALI                   824             0.631461
# 2           2  TCGA-3C-AALJ                    72             0.055176
# 3           3  TCGA-3C-AALK                    69             0.052877
# 4           4  TCGA-4H-AAAK                    37             0.028354
# 5           5  TCGA-5L-AAT0                   282             0.216107
# 6           6  TCGA-5T-A9QA                    93             0.071269
# 7           7  TCGA-A1-A0SB                    19             0.014560
# 8           8  TCGA-A1-A0SD                    44             0.033719
# 9           9  TCGA-A1-A0SE                    39             0.029887

# %%
plt.hist(PatientMut['Mutation Per Patient'], bins=[5, 10, 25, 50, 100, 200, 500], edgecolor="black")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 plt.hist(PatientMut['Mutation Per Patient'], bins=[5, 10, 25, 50, 100, 200, 500], edgecolor="black")
#       2 plt.show()
#
# NameError: name 'PatientMut' is not defined

# %%
plt.hist(PatientMut['count'], bins=n_mutations, edgecolor="white")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'count'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
binwidth = 5
plt.hist(PatientMut['count'], bins=range(min(PatientMut), max(PatientMut) + binwidth, binwidth),
         edgecolor="yellow", color="brown")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'count'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
topmost= df3.nlargest(10,['count'])
topmost
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [43], in <cell line: 1>()
# ----> 1 topmost= df3.nlargest(10,['count'])
#       2 topmost
#
# NameError: name 'df3' is not defined

# %%
PanM_PanS_PanP.head(3)
# Out:
#   Hugo_Symbol  Entrez_Gene_Id Center NCBI_Build Chromosome  Start_Position  \
# 0       GATA3          2625.0      .     GRCh37         10         8115874
# 1      MALAT1        378938.0      .     GRCh37         11        65272906
# 2       CD248         57124.0      .     GRCh37         11        66082467
#
#    End_Position Strand                         Consequence  \
# 0       8115875      +                  frameshift_variant
# 1      65272908      +  non_coding_transcript_exon_variant
# 2      66082467      +                    missense_variant
#
#   Variant_Classification  ... WEIGHT IN_PANCANPATHWAYS_FREEZE OS_STATUS  \
# 0        Frame_Shift_Ins  ...    NaN                      Yes  0:LIVING
# 1                    RNA  ...    NaN                      Yes  0:LIVING
# 2      Missense_Mutation  ...    NaN                      Yes  0:LIVING
#
#     OS_MONTHS                  DSS_STATUS  DSS_MONTHS             DFS_STATUS  \
# ...

# %%
countcellrepeats = PanM_PanS_PanP['Start_Position'].value_counts()[8115874], PanM_PanS_PanP['Chromosome'].value_counts()[10] 
countcellrepeats
# Out:
# (11, 6129)

# %%
PanM_PanS_PanP.iloc[0,5]
# Out:
# '10'

# %%
 if PanM_PanS_PanP.iloc[0,5] == 8115874:
        print(PanM_PanS_PanP.iloc[0,4], PanM_PanS_PanP.iloc[0,5])
# Out:
# 10 8115874

# %%
df = PanM_PanS_PanP.colncat()'Hugo_Symbol', 'Chromosome', 'Start_Position' ]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [93], in <cell line: 1>()
# ----> 1 df = PanM_PanS_PanP.pd.concat('Hugo_Symbol', 'Chromosome', 'Start_Position' )
#
# File ~\Anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'pd'
